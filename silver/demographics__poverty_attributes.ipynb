# %%
# %sql
SELECT
  Attribute AS attribute_name,
  attribute_description
FROM
  bronze_dev.economic_research_service.poverty_attributes;

# %%
# %sql
CREATE OR REPLACE TABLE silver_dev.demographics.poverty_attributes AS 
SELECT
  Attribute AS attribute_name,
  attribute_description
FROM
  bronze_dev.economic_research_service.poverty_attributes;
