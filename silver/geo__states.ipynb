# %%
# %sql
CREATE OR REPLACE TABLE silver_dev.geo.states AS
SELECT
  StateFIPS20 AS state_fips, 
  StateName20 AS state_name,
  state_abbrev AS state_abbreviation,
  is_territory
FROM
  bronze_dev.geo.states

# %%
# %sql
SELECT * FROM silver_dev.geo.states
