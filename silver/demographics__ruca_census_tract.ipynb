# %%
# %sql
SELECT * FROM bronze_dev.ruca.ruca_census_tract

# %%
# %sql
SELECT 
  COUNT(*), 
  COUNT(DISTINCT TractFIPS20),
  COUNT(DISTINCT TractFIPS23)

 FROM bronze_dev.ruca.ruca_census_tract

# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

# %%
import importlib
import utils.helpers

importlib.reload(utils.helpers)

# %%
df = spark.table("bronze_dev.ruca.ruca_census_tract")

df.columns

# %%
df_prepped = utils.helpers.prep_silver_df(df)
display(df_prepped)

# %%
df_prepped.write \
  .format("delta") \
  .mode("overwrite") \
  .option("mergeSchema", "true") \
  .saveAsTable("silver_dev.demographics.ruca_census_tract")

# %%
# %sql
SELECT * FROM silver_dev.demographics.ruca_census_tract
