# %%
import importlib
import utils.helpers

importlib.reload(utils.helpers)

# %%
file_path_parquet = "/Volumes/bronze_dev/nppes_npi_registry/raw/npidata_pfile_20050523-20260308_column_subset.parquet"

df = spark.read.format("parquet") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(file_path_parquet)

display(df)

# %%
df_prepped = utils.helpers.prep_bronze_df(df)

# %%
df_prepped.write.format("delta") \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("bronze_dev.nppes_npi_registry.npi")

# %%
spark.table("bronze_dev.nppes_npi_registry.npi").printSchema()
