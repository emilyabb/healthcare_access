# %%
# %load_ext autoreload
# %autoreload 2
# Enables autoreload; learn more at https://docs.databricks.com/en/files/workspace-modules.html#autoreload-for-python-modules
# To disable autoreload; run %autoreload 0

import importlib
import utils.helpers

importlib.reload(utils.helpers)

# %%
file_path_csv = "/Volumes/bronze_dev/seeds/raw/nucc_taxonomy_251.csv"

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load(file_path_csv)

display(df)

# %%
df_clean_columns = utils.helpers.prep_bronze_df(df)
display(df_clean_columns)

# %%
df_clean_columns.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze_dev.seeds.nucc_provider_taxonomy_codes")

# %%
# %sql
--DROP TABLE bronze_dev.seeds.nucc_provider_taxonomy_codes
SELECT * FROM bronze_dev.seeds.nucc_provider_taxonomy_codes
