-- %%
CREATE CATALOG bronze_dev;
CREATE CATALOG silver_dev;
CREATE CATALOG gold_dev;


/* */
CREATE SCHEMA bronze_dev.economic_research_service;
CREATE VOLUME bronze_dev.economic_research_service.raw;
CREATE SCHEMA bronze_dev.geo;


CREATE SCHEMA silver_dev.geo;
CREATE SCHEMA silver_dev.demographics;
CREATE SCHEMA silver_dev.healthcare;



CREATE SCHEMA gold_dev.geo;
CREATE SCHEMA gold_dev.demographics;
CREATE SCHEMA gold_dev.healthcare;
CREATE SCHEMA gold_dev.unified;

DROP TABLE bronze_dev.economic_research_service.poverty;
DROP TABLE bronze_dev.census_bureau.county_pop;
DROP TABLE silver_dev.economic_research_service.poverty;
DROP TABLE silver_dev.economic_research_service.poverty_attributes;
DROP SCHEMA silver_dev.economic_research_service;

DROP TABLE silver_dev.nppes_npi_registry.npi;
DROP SCHEMA silver_dev.nppes_npi_registry;

DROP TABLE silver_dev.ruca.ruca_census_tract;
DROP TABLE silver_dev.ruca.ruca_codes;
DROP SCHEMA silver_dev.ruca;

DROP SCHEMA silver_dev.seeds;


CREATE SCHEMA gold.county_unified_county;

/* */
